# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Directorio base
link = '/content/Table_LDN 1588_'
# Lista para almacenar los nombres de archivo
files = []
# Generar los nombres de archivo
for numero in range(2, 25):
    file = f'{link}{numero}.csv'
    variable_name = f'cat1_err_{numero}'
    files.append(file)

# %%
catalogos = {}  # Usaremos un diccionario para almacenar los catálogos

for catalogo_num in range(2, 25):
    file_name = f'file_{catalogo_num}'  # Nombre de la variable del archivo
    catalogo = pd.read_csv(globals()[file_name], delimiter=',', header=0)
    catalogos[f'catalogo_{catalogo_num}'] = catalogo

# %%
file_2='/content/Table_LDN 1588_2.csv'
file_3='/content/Table_LDN 1588_3.csv'
file_4='/content/Table_LDN 1588_4.csv'
file_5='/content/Table_LDN 1588_5.csv'
file_6='/content/Table_LDN 1588_6.csv'
file_7='/content/Table_LDN 1588_7.csv'
file_8='/content/Table_LDN 1588_8.csv'
file_9='/content/Table_LDN 1588_9.csv'
file_10='/content/Table_LDN 1588_10.csv'
file_11='/content/Table_LDN 1588_11.csv'
file_12='/content/Table_LDN 1588_12.csv'
file_13='/content/Table_LDN 1588_13.csv'
file_14='/content/Table_LDN 1588_14.csv'
file_15='/content/Table_LDN 1588_15.csv'
file_16='/content/Table_LDN 1588_16.csv'
file_17='/content/Table_LDN 1588_17.csv'
file_18='/content/Table_LDN 1588_18.csv'
file_19='/content/Table_LDN 1588_19.csv'
file_20='/content/Table_LDN 1588_20.csv'
file_21='/content/Table_LDN 1588_21.csv'
file_22='/content/Table_LDN 1588_22.csv'
file_23='/content/Table_LDN 1588_23.csv'
file_24='/content/Table_LDN 1588_24.csv'
file_25='/content/Table_LDN 1588_25.csv'

catalogo_2 = pd.read_csv(file_2,delimiter=',',header=0)
catalogo_3 = pd.read_csv(file_3,delimiter=',',header=0)
catalogo_4 = pd.read_csv(file_4,delimiter=',',header=0)
catalogo_5 = pd.read_csv(file_5,delimiter=',',header=0)
catalogo_6 = pd.read_csv(file_6,delimiter=',',header=0)
catalogo_7 = pd.read_csv(file_7,delimiter=',',header=0)
catalogo_8 = pd.read_csv(file_8,delimiter=',',header=0)
catalogo_9 = pd.read_csv(file_9,delimiter=',',header=0)
catalogo_10 = pd.read_csv(file_10,delimiter=',',header=0)
catalogo_11 = pd.read_csv(file_11,delimiter=',',header=0)
catalogo_12 = pd.read_csv(file_12,delimiter=',',header=0)
catalogo_13 = pd.read_csv(file_13,delimiter=',',header=0)
catalogo_14 = pd.read_csv(file_14,delimiter=',',header=0)
catalogo_15 = pd.read_csv(file_15,delimiter=',',header=0)
catalogo_16 = pd.read_csv(file_16,delimiter=',',header=0)
catalogo_17 = pd.read_csv(file_17,delimiter=',',header=0)
catalogo_18 = pd.read_csv(file_18,delimiter=',',header=0)
catalogo_19 = pd.read_csv(file_19,delimiter=',',header=0)
catalogo_20 = pd.read_csv(file_20,delimiter=',',header=0)
catalogo_21 = pd.read_csv(file_21,delimiter=',',header=0)
catalogo_22 = pd.read_csv(file_22,delimiter=',',header=0)
catalogo_23= pd.read_csv(file_23,delimiter=',',header=0)
catalogo_24 = pd.read_csv(file_24,delimiter=',',header=0)

# %%
def err_mag1(file):
  cat_selected=file.loc[(file['1_mag_err_0']/file['1_mag_0']<=0.2)]
  return cat_selected

def err_mag2(file):
  cat_selected=file.loc[(file['2_mag_err_1']/file['2_mag_1']<=0.2)]
  return cat_selected

def err_mag3(file):
  cat_selected=file.loc[(file['3_mag_err_0']/file['3_mag_0']<=0.2)]
  return cat_selected

def err_mag4(file):
  cat_selected=file.loc[(file['4_mag_err_0']/file['4_mag_0']<=0.2)]
  return cat_selected

# %%
cat1_err_2=err_mag1(catalogo_2).rename(columns={'1_mag_0': 'mag1_2','2_mag_1': 'mag2_2','3_mag_0': 'mag3_2','4_mag_0': 'mag4_2'})
cat1_err_3=err_mag1(catalogo_3).rename(columns={'1_mag_0': 'mag1_3','2_mag_1': 'mag2_3','3_mag_0': 'mag3_3','4_mag_0': 'mag4_3'})
cat1_err_4=err_mag1(catalogo_4).rename(columns={'1_mag_0': 'mag1_4','2_mag_1': 'mag2_4','3_mag_0': 'mag3_4','4_mag_0': 'mag4_4'})
cat1_err_5=err_mag1(catalogo_5).rename(columns={'1_mag_0': 'mag1_5','2_mag_1': 'mag2_5','3_mag_0': 'mag3_5','4_mag_0': 'mag4_5'})
cat1_err_6=err_mag1(catalogo_6).rename(columns={'1_mag_0': 'mag1_6','2_mag_1': 'mag2_6','3_mag_0': 'mag3_6','4_mag_0': 'mag4_6'})
cat1_err_7=err_mag1(catalogo_7).rename(columns={'1_mag_0': 'mag1_7','2_mag_1': 'mag2_7','3_mag_0': 'mag3_7','4_mag_0': 'mag4_7'})
cat1_err_8=err_mag1(catalogo_8).rename(columns={'1_mag_0': 'mag1_8','2_mag_1': 'mag2_8','3_mag_0': 'mag3_8','4_mag_0': 'mag4_8'})
cat1_err_9=err_mag1(catalogo_9).rename(columns={'1_mag_0': 'mag1_9','2_mag_1': 'mag2_9','3_mag_0': 'mag3_9','4_mag_0': 'mag4_9'})
cat1_err_10=err_mag1(catalogo_10).rename(columns={'1_mag_0': 'mag1_10','2_mag_1': 'mag2_10','3_mag_0': 'mag3_10','4_mag_0': 'mag4_10'})
cat1_err_11=err_mag1(catalogo_11).rename(columns={'1_mag_0': 'mag1_11','2_mag_1': 'mag2_11','3_mag_0': 'mag3_11','4_mag_0': 'mag4_11'})
cat1_err_12=err_mag1(catalogo_12).rename(columns={'1_mag_0': 'mag1_12','2_mag_1': 'mag2_12','3_mag_0': 'mag3_12','4_mag_0': 'mag4_12'})
cat1_err_13=err_mag1(catalogo_13).rename(columns={'1_mag_0': 'mag1_13','2_mag_1': 'mag2_13','3_mag_0': 'mag3_13','4_mag_0': 'mag4_13'})
cat1_err_14=err_mag1(catalogo_14).rename(columns={'1_mag_0': 'mag1_14','2_mag_1': 'mag2_14','3_mag_0': 'mag3_14','4_mag_0': 'mag4_14'})
cat1_err_15=err_mag1(catalogo_15).rename(columns={'1_mag_0': 'mag1_15','2_mag_1': 'mag2_15','3_mag_0': 'mag3_15','4_mag_0': 'mag4_15'})
cat1_err_16=err_mag1(catalogo_16).rename(columns={'1_mag_0': 'mag1_16','2_mag_1': 'mag2_16','3_mag_0': 'mag3_16','4_mag_0': 'mag4_16'})
cat1_err_17=err_mag1(catalogo_17).rename(columns={'1_mag_0': 'mag1_17','2_mag_1': 'mag2_17','3_mag_0': 'mag3_17','4_mag_0': 'mag4_17'})
cat1_err_18=err_mag1(catalogo_18).rename(columns={'1_mag_0': 'mag1_18','2_mag_1': 'mag2_18','3_mag_0': 'mag3_18','4_mag_0': 'mag4_18'})
cat1_err_19=err_mag1(catalogo_19).rename(columns={'1_mag_0': 'mag1_19','2_mag_1': 'mag2_19','3_mag_0': 'mag3_19','4_mag_0': 'mag4_19'})
cat1_err_20=err_mag1(catalogo_20).rename(columns={'1_mag_0': 'mag1_20','2_mag_1': 'mag2_20','3_mag_0': 'mag3_20','4_mag_0': 'mag4_20'})
cat1_err_21=err_mag1(catalogo_21).rename(columns={'1_mag_0': 'mag1_21','2_mag_1': 'mag2_21','3_mag_0': 'mag3_21','4_mag_0': 'mag4_21'})
cat1_err_22=err_mag1(catalogo_22).rename(columns={'1_mag_0': 'mag1_22','2_mag_1': 'mag2_22','3_mag_0': 'mag3_22','4_mag_0': 'mag4_22'})
cat1_err_23=err_mag1(catalogo_23).rename(columns={'1_mag_0': 'mag1_23','2_mag_1': 'mag2_23','3_mag_0': 'mag3_23','4_mag_0': 'mag4_23'})
cat1_err_24=err_mag1(catalogo_24).rename(columns={'1_mag_0': 'mag1_24','2_mag_1': 'mag2_24','3_mag_0': 'mag3_24','4_mag_0': 'mag4_24'})

cat2_err_2=err_mag2(catalogo_2).rename(columns={'1_mag_0': 'mag1_2','2_mag_1': 'mag2_2','3_mag_0': 'mag3_2','4_mag_0': 'mag4_2'})
cat2_err_3=err_mag2(catalogo_3).rename(columns={'1_mag_0': 'mag1_3','2_mag_1': 'mag2_3','3_mag_0': 'mag3_3','4_mag_0': 'mag4_3'})
cat2_err_4=err_mag2(catalogo_4).rename(columns={'1_mag_0': 'mag1_4','2_mag_1': 'mag2_4','3_mag_0': 'mag3_4','4_mag_0': 'mag4_4'})
cat2_err_5=err_mag2(catalogo_5).rename(columns={'1_mag_0': 'mag1_5','2_mag_1': 'mag2_5','3_mag_0': 'mag3_5','4_mag_0': 'mag4_5'})
cat2_err_6=err_mag2(catalogo_6).rename(columns={'1_mag_0': 'mag1_6','2_mag_1': 'mag2_6','3_mag_0': 'mag3_6','4_mag_0': 'mag4_6'})
cat2_err_7=err_mag2(catalogo_7).rename(columns={'1_mag_0': 'mag1_7','2_mag_1': 'mag2_7','3_mag_0': 'mag3_7','4_mag_0': 'mag4_7'})
cat2_err_8=err_mag2(catalogo_8).rename(columns={'1_mag_0': 'mag1_8','2_mag_1': 'mag2_8','3_mag_0': 'mag3_8','4_mag_0': 'mag4_8'})
cat2_err_9=err_mag2(catalogo_9).rename(columns={'1_mag_0': 'mag1_9','2_mag_1': 'mag2_9','3_mag_0': 'mag3_9','4_mag_0': 'mag4_9'})
cat2_err_10=err_mag2(catalogo_10).rename(columns={'1_mag_0': 'mag1_10','2_mag_1': 'mag2_10','3_mag_0': 'mag3_10','4_mag_0': 'mag4_10'})
cat2_err_11=err_mag2(catalogo_11).rename(columns={'1_mag_0': 'mag1_11','2_mag_1': 'mag2_11','3_mag_0': 'mag3_11','4_mag_0': 'mag4_11'})
cat2_err_12=err_mag2(catalogo_12).rename(columns={'1_mag_0': 'mag1_12','2_mag_1': 'mag2_12','3_mag_0': 'mag3_12','4_mag_0': 'mag4_12'})
cat2_err_13=err_mag2(catalogo_13).rename(columns={'1_mag_0': 'mag1_13','2_mag_1': 'mag2_13','3_mag_0': 'mag3_13','4_mag_0': 'mag4_13'})
cat2_err_14=err_mag2(catalogo_14).rename(columns={'1_mag_0': 'mag1_14','2_mag_1': 'mag2_14','3_mag_0': 'mag3_14','4_mag_0': 'mag4_14'})
cat2_err_15=err_mag2(catalogo_15).rename(columns={'1_mag_0': 'mag1_15','2_mag_1': 'mag2_15','3_mag_0': 'mag3_15','4_mag_0': 'mag4_15'})
cat2_err_16=err_mag2(catalogo_16).rename(columns={'1_mag_0': 'mag1_16','2_mag_1': 'mag2_16','3_mag_0': 'mag3_16','4_mag_0': 'mag4_16'})
cat2_err_17=err_mag2(catalogo_17).rename(columns={'1_mag_0': 'mag1_17','2_mag_1': 'mag2_17','3_mag_0': 'mag3_17','4_mag_0': 'mag4_17'})
cat2_err_18=err_mag2(catalogo_18).rename(columns={'1_mag_0': 'mag1_18','2_mag_1': 'mag2_18','3_mag_0': 'mag3_18','4_mag_0': 'mag4_18'})
cat2_err_19=err_mag2(catalogo_19).rename(columns={'1_mag_0': 'mag1_19','2_mag_1': 'mag2_19','3_mag_0': 'mag3_19','4_mag_0': 'mag4_19'})
cat2_err_20=err_mag2(catalogo_20).rename(columns={'1_mag_0': 'mag1_20','2_mag_1': 'mag2_20','3_mag_0': 'mag3_20','4_mag_0': 'mag4_20'})
cat2_err_21=err_mag2(catalogo_21).rename(columns={'1_mag_0': 'mag1_21','2_mag_1': 'mag2_21','3_mag_0': 'mag3_21','4_mag_0': 'mag4_21'})
cat2_err_22=err_mag2(catalogo_22).rename(columns={'1_mag_0': 'mag1_22','2_mag_1': 'mag2_22','3_mag_0': 'mag3_22','4_mag_0': 'mag4_22'})
cat2_err_23=err_mag2(catalogo_23).rename(columns={'1_mag_0': 'mag1_23','2_mag_1': 'mag2_23','3_mag_0': 'mag3_23','4_mag_0': 'mag4_23'})
cat2_err_24=err_mag2(catalogo_24).rename(columns={'1_mag_0': 'mag1_24','2_mag_1': 'mag2_24','3_mag_0': 'mag3_24','4_mag_0': 'mag4_24'})

cat3_err_2=err_mag3(catalogo_2).rename(columns={'1_mag_0': 'mag1_2','2_mag_1': 'mag2_2','3_mag_0': 'mag3_2','4_mag_0': 'mag4_2'})
cat3_err_3=err_mag3(catalogo_3).rename(columns={'1_mag_0': 'mag1_3','2_mag_1': 'mag2_3','3_mag_0': 'mag3_3','4_mag_0': 'mag4_3'})
cat3_err_4=err_mag3(catalogo_4).rename(columns={'1_mag_0': 'mag1_4','2_mag_1': 'mag2_4','3_mag_0': 'mag3_4','4_mag_0': 'mag4_4'})
cat3_err_5=err_mag3(catalogo_5).rename(columns={'1_mag_0': 'mag1_5','2_mag_1': 'mag2_5','3_mag_0': 'mag3_5','4_mag_0': 'mag4_5'})
cat3_err_6=err_mag3(catalogo_6).rename(columns={'1_mag_0': 'mag1_6','2_mag_1': 'mag2_6','3_mag_0': 'mag3_6','4_mag_0': 'mag4_6'})
cat3_err_7=err_mag3(catalogo_7).rename(columns={'1_mag_0': 'mag1_7','2_mag_1': 'mag2_7','3_mag_0': 'mag3_7','4_mag_0': 'mag4_7'})
cat3_err_8=err_mag3(catalogo_8).rename(columns={'1_mag_0': 'mag1_8','2_mag_1': 'mag2_8','3_mag_0': 'mag3_8','4_mag_0': 'mag4_8'})
cat3_err_9=err_mag3(catalogo_9).rename(columns={'1_mag_0': 'mag1_9','2_mag_1': 'mag2_9','3_mag_0': 'mag3_9','4_mag_0': 'mag4_9'})
cat3_err_10=err_mag3(catalogo_10).rename(columns={'1_mag_0': 'mag1_10','2_mag_1': 'mag2_10','3_mag_0': 'mag3_10','4_mag_0': 'mag4_10'})
cat3_err_11=err_mag3(catalogo_11).rename(columns={'1_mag_0': 'mag1_11','2_mag_1': 'mag2_11','3_mag_0': 'mag3_11','4_mag_0': 'mag4_11'})
cat3_err_12=err_mag3(catalogo_12).rename(columns={'1_mag_0': 'mag1_12','2_mag_1': 'mag2_12','3_mag_0': 'mag3_12','4_mag_0': 'mag4_12'})
cat3_err_13=err_mag3(catalogo_13).rename(columns={'1_mag_0': 'mag1_13','2_mag_1': 'mag2_13','3_mag_0': 'mag3_13','4_mag_0': 'mag4_13'})
cat3_err_14=err_mag3(catalogo_14).rename(columns={'1_mag_0': 'mag1_14','2_mag_1': 'mag2_14','3_mag_0': 'mag3_14','4_mag_0': 'mag4_14'})
cat3_err_15=err_mag3(catalogo_15).rename(columns={'1_mag_0': 'mag1_15','2_mag_1': 'mag2_15','3_mag_0': 'mag3_15','4_mag_0': 'mag4_15'})
cat3_err_16=err_mag3(catalogo_16).rename(columns={'1_mag_0': 'mag1_16','2_mag_1': 'mag2_16','3_mag_0': 'mag3_16','4_mag_0': 'mag4_16'})
cat3_err_17=err_mag3(catalogo_17).rename(columns={'1_mag_0': 'mag1_17','2_mag_1': 'mag2_17','3_mag_0': 'mag3_17','4_mag_0': 'mag4_17'})
cat3_err_18=err_mag3(catalogo_18).rename(columns={'1_mag_0': 'mag1_18','2_mag_1': 'mag2_18','3_mag_0': 'mag3_18','4_mag_0': 'mag4_18'})
cat3_err_19=err_mag3(catalogo_19).rename(columns={'1_mag_0': 'mag1_19','2_mag_1': 'mag2_19','3_mag_0': 'mag3_19','4_mag_0': 'mag4_19'})
cat3_err_20=err_mag3(catalogo_20).rename(columns={'1_mag_0': 'mag1_20','2_mag_1': 'mag2_20','3_mag_0': 'mag3_20','4_mag_0': 'mag4_20'})
cat3_err_21=err_mag3(catalogo_21).rename(columns={'1_mag_0': 'mag1_21','2_mag_1': 'mag2_21','3_mag_0': 'mag3_21','4_mag_0': 'mag4_21'})
cat3_err_22=err_mag3(catalogo_22).rename(columns={'1_mag_0': 'mag1_22','2_mag_1': 'mag2_22','3_mag_0': 'mag3_22','4_mag_0': 'mag4_22'})
cat3_err_23=err_mag3(catalogo_23).rename(columns={'1_mag_0': 'mag1_23','2_mag_1': 'mag2_23','3_mag_0': 'mag3_23','4_mag_0': 'mag4_23'})
cat3_err_24=err_mag3(catalogo_24).rename(columns={'1_mag_0': 'mag1_24','2_mag_1': 'mag2_24','3_mag_0': 'mag3_24','4_mag_0': 'mag4_24'})

cat4_err_2=err_mag4(catalogo_2).rename(columns={'1_mag_0': 'mag1_2','2_mag_1': 'mag2_2','3_mag_0': 'mag3_2','4_mag_0': 'mag4_2'})
cat4_err_3=err_mag4(catalogo_3).rename(columns={'1_mag_0': 'mag1_3','2_mag_1': 'mag2_3','3_mag_0': 'mag3_3','4_mag_0': 'mag4_3'})
cat4_err_4=err_mag4(catalogo_4).rename(columns={'1_mag_0': 'mag1_4','2_mag_1': 'mag2_4','3_mag_0': 'mag3_4','4_mag_0': 'mag4_4'})
cat4_err_5=err_mag4(catalogo_5).rename(columns={'1_mag_0': 'mag1_5','2_mag_1': 'mag2_5','3_mag_0': 'mag3_5','4_mag_0': 'mag4_5'})
cat4_err_6=err_mag4(catalogo_6).rename(columns={'1_mag_0': 'mag1_6','2_mag_1': 'mag2_6','3_mag_0': 'mag3_6','4_mag_0': 'mag4_6'})
cat4_err_7=err_mag4(catalogo_7).rename(columns={'1_mag_0': 'mag1_7','2_mag_1': 'mag2_7','3_mag_0': 'mag3_7','4_mag_0': 'mag4_7'})
cat4_err_8=err_mag4(catalogo_8).rename(columns={'1_mag_0': 'mag1_8','2_mag_1': 'mag2_8','3_mag_0': 'mag3_8','4_mag_0': 'mag4_8'})
cat4_err_9=err_mag4(catalogo_9).rename(columns={'1_mag_0': 'mag1_9','2_mag_1': 'mag2_9','3_mag_0': 'mag3_9','4_mag_0': 'mag4_9'})
cat4_err_10=err_mag4(catalogo_10).rename(columns={'1_mag_0': 'mag1_10','2_mag_1': 'mag2_10','3_mag_0': 'mag3_10','4_mag_0': 'mag4_10'})
cat4_err_11=err_mag4(catalogo_11).rename(columns={'1_mag_0': 'mag1_11','2_mag_1': 'mag2_11','3_mag_0': 'mag3_11','4_mag_0': 'mag4_11'})
cat4_err_12=err_mag4(catalogo_12).rename(columns={'1_mag_0': 'mag1_12','2_mag_1': 'mag2_12','3_mag_0': 'mag3_12','4_mag_0': 'mag4_12'})
cat4_err_13=err_mag4(catalogo_13).rename(columns={'1_mag_0': 'mag1_13','2_mag_1': 'mag2_13','3_mag_0': 'mag3_13','4_mag_0': 'mag4_13'})
cat4_err_14=err_mag4(catalogo_14).rename(columns={'1_mag_0': 'mag1_14','2_mag_1': 'mag2_14','3_mag_0': 'mag3_14','4_mag_0': 'mag4_14'})
cat4_err_15=err_mag4(catalogo_15).rename(columns={'1_mag_0': 'mag1_15','2_mag_1': 'mag2_15','3_mag_0': 'mag3_15','4_mag_0': 'mag4_15'})
cat4_err_16=err_mag4(catalogo_16).rename(columns={'1_mag_0': 'mag1_16','2_mag_1': 'mag2_16','3_mag_0': 'mag3_16','4_mag_0': 'mag4_16'})
cat4_err_17=err_mag4(catalogo_17).rename(columns={'1_mag_0': 'mag1_17','2_mag_1': 'mag2_17','3_mag_0': 'mag3_17','4_mag_0': 'mag4_17'})
cat4_err_18=err_mag4(catalogo_18).rename(columns={'1_mag_0': 'mag1_18','2_mag_1': 'mag2_18','3_mag_0': 'mag3_18','4_mag_0': 'mag4_18'})
cat4_err_19=err_mag4(catalogo_19).rename(columns={'1_mag_0': 'mag1_19','2_mag_1': 'mag2_19','3_mag_0': 'mag3_19','4_mag_0': 'mag4_19'})
cat4_err_20=err_mag4(catalogo_20).rename(columns={'1_mag_0': 'mag1_20','2_mag_1': 'mag2_20','3_mag_0': 'mag3_20','4_mag_0': 'mag4_20'})
cat4_err_21=err_mag4(catalogo_21).rename(columns={'1_mag_0': 'mag1_21','2_mag_1': 'mag2_21','3_mag_0': 'mag3_21','4_mag_0': 'mag4_21'})
cat4_err_22=err_mag4(catalogo_22).rename(columns={'1_mag_0': 'mag1_22','2_mag_1': 'mag2_22','3_mag_0': 'mag3_22','4_mag_0': 'mag4_22'})
cat4_err_23=err_mag4(catalogo_23).rename(columns={'1_mag_0': 'mag1_23','2_mag_1': 'mag2_23','3_mag_0': 'mag3_23','4_mag_0': 'mag4_23'})
cat4_err_24=err_mag4(catalogo_24).rename(columns={'1_mag_0': 'mag1_24','2_mag_1': 'mag2_24','3_mag_0': 'mag3_24','4_mag_0': 'mag4_24'})

# %%
cat_1_mag1 = pd.merge(cat1_err_2, cat1_err_3, on='OBJECT_ID', how='inner')
cat_2_mag1 = pd.merge(cat_1_mag1, cat1_err_4, on='OBJECT_ID', how='inner')
cat_3_mag1 = pd.merge(cat_2_mag1, cat1_err_5, on='OBJECT_ID', how='inner')
cat_4_mag1 = pd.merge(cat_3_mag1, cat1_err_6, on='OBJECT_ID', how='inner')
cat_5_mag1 = pd.merge(cat_4_mag1, cat1_err_7, on='OBJECT_ID', how='inner')
cat_6_mag1 = pd.merge(cat_5_mag1, cat1_err_8, on='OBJECT_ID', how='inner')
cat_7_mag1 = pd.merge(cat_6_mag1, cat1_err_9, on='OBJECT_ID', how='inner')
cat_8_mag1 = pd.merge(cat_7_mag1, cat1_err_10, on='OBJECT_ID', how='inner')
cat_9_mag1 = pd.merge(cat_8_mag1, cat1_err_11, on='OBJECT_ID', how='inner')
cat_10_mag1 = pd.merge(cat_9_mag1, cat1_err_12, on='OBJECT_ID', how='inner')
cat_11_mag1 = pd.merge(cat_10_mag1, cat1_err_13, on='OBJECT_ID', how='inner')
cat_12_mag1 = pd.merge(cat_11_mag1, cat1_err_14, on='OBJECT_ID', how='inner')
cat_13_mag1 = pd.merge(cat_12_mag1, cat1_err_15, on='OBJECT_ID', how='inner')
cat_14_mag1 = pd.merge(cat_13_mag1, cat1_err_16, on='OBJECT_ID', how='inner')
cat_15_mag1 = pd.merge(cat_14_mag1, cat1_err_17, on='OBJECT_ID', how='inner')
cat_16_mag1 = pd.merge(cat_15_mag1, cat1_err_18, on='OBJECT_ID', how='inner')
cat_17_mag1 = pd.merge(cat_16_mag1, cat1_err_19, on='OBJECT_ID', how='inner')
cat_18_mag1 = pd.merge(cat_17_mag1, cat1_err_20, on='OBJECT_ID', how='inner')
cat_19_mag1 = pd.merge(cat_18_mag1, cat1_err_21, on='OBJECT_ID', how='inner')
cat_20_mag1 = pd.merge(cat_19_mag1, cat1_err_22, on='OBJECT_ID', how='inner')
cat_21_mag1 = pd.merge(cat_20_mag1, cat1_err_23, on='OBJECT_ID', how='inner')
cat_22_mag1 = pd.merge(cat_21_mag1, cat1_err_24, on='OBJECT_ID', how='inner')

cat_1_mag2 = pd.merge(cat2_err_2, cat2_err_3, on='OBJECT_ID', how='inner')
cat_2_mag2 = pd.merge(cat_1_mag2, cat2_err_4, on='OBJECT_ID', how='inner')
cat_3_mag2 = pd.merge(cat_2_mag2, cat2_err_5, on='OBJECT_ID', how='inner')
cat_4_mag2 = pd.merge(cat_3_mag2, cat2_err_6, on='OBJECT_ID', how='inner')
cat_5_mag2 = pd.merge(cat_4_mag2, cat2_err_7, on='OBJECT_ID', how='inner')
cat_6_mag2 = pd.merge(cat_5_mag2, cat2_err_8, on='OBJECT_ID', how='inner')
cat_7_mag2 = pd.merge(cat_6_mag2, cat2_err_9, on='OBJECT_ID', how='inner')
cat_8_mag2 = pd.merge(cat_7_mag2, cat2_err_10, on='OBJECT_ID', how='inner')
cat_9_mag2 = pd.merge(cat_8_mag2, cat2_err_11, on='OBJECT_ID', how='inner')
cat_10_mag2 = pd.merge(cat_9_mag2, cat2_err_12, on='OBJECT_ID', how='inner')
cat_11_mag2 = pd.merge(cat_10_mag2, cat2_err_13, on='OBJECT_ID', how='inner')
cat_12_mag2 = pd.merge(cat_11_mag2, cat2_err_14, on='OBJECT_ID', how='inner')
cat_13_mag2 = pd.merge(cat_12_mag2, cat2_err_15, on='OBJECT_ID', how='inner')
cat_14_mag2 = pd.merge(cat_13_mag2, cat2_err_16, on='OBJECT_ID', how='inner')
cat_15_mag2 = pd.merge(cat_14_mag2, cat2_err_17, on='OBJECT_ID', how='inner')
cat_16_mag2 = pd.merge(cat_15_mag2, cat2_err_18, on='OBJECT_ID', how='inner')
cat_17_mag2 = pd.merge(cat_16_mag2, cat2_err_19, on='OBJECT_ID', how='inner')
cat_18_mag2 = pd.merge(cat_17_mag2, cat2_err_20, on='OBJECT_ID', how='inner')
cat_19_mag2 = pd.merge(cat_18_mag2, cat2_err_21, on='OBJECT_ID', how='inner')
cat_20_mag2 = pd.merge(cat_19_mag2, cat2_err_22, on='OBJECT_ID', how='inner')
cat_21_mag2 = pd.merge(cat_20_mag2, cat2_err_23, on='OBJECT_ID', how='inner')
cat_22_mag2 = pd.merge(cat_21_mag2, cat2_err_24, on='OBJECT_ID', how='inner')

cat_1_mag3 = pd.merge(cat3_err_2, cat3_err_3, on='OBJECT_ID', how='inner')
cat_2_mag3 = pd.merge(cat_1_mag3, cat3_err_4, on='OBJECT_ID', how='inner')
cat_3_mag3 = pd.merge(cat_2_mag3, cat3_err_5, on='OBJECT_ID', how='inner')
cat_4_mag3 = pd.merge(cat_3_mag3, cat3_err_6, on='OBJECT_ID', how='inner')
cat_5_mag3 = pd.merge(cat_4_mag3, cat3_err_7, on='OBJECT_ID', how='inner')
cat_6_mag3 = pd.merge(cat_5_mag3, cat3_err_8, on='OBJECT_ID', how='inner')
cat_7_mag3 = pd.merge(cat_6_mag3, cat3_err_9, on='OBJECT_ID', how='inner')
cat_8_mag3 = pd.merge(cat_7_mag3, cat3_err_10, on='OBJECT_ID', how='inner')
cat_9_mag3 = pd.merge(cat_8_mag3, cat3_err_11, on='OBJECT_ID', how='inner')
cat_10_mag3 = pd.merge(cat_9_mag3, cat3_err_12, on='OBJECT_ID', how='inner')
cat_11_mag3 = pd.merge(cat_10_mag3, cat3_err_13, on='OBJECT_ID', how='inner')
cat_12_mag3 = pd.merge(cat_11_mag3, cat3_err_14, on='OBJECT_ID', how='inner')
cat_13_mag3 = pd.merge(cat_12_mag3, cat3_err_15, on='OBJECT_ID', how='inner')
cat_14_mag3 = pd.merge(cat_13_mag3, cat3_err_16, on='OBJECT_ID', how='inner')
cat_15_mag3 = pd.merge(cat_14_mag3, cat3_err_17, on='OBJECT_ID', how='inner')
cat_16_mag3 = pd.merge(cat_15_mag3, cat3_err_18, on='OBJECT_ID', how='inner')
cat_17_mag3 = pd.merge(cat_16_mag3, cat3_err_19, on='OBJECT_ID', how='inner')
cat_18_mag3 = pd.merge(cat_17_mag3, cat3_err_20, on='OBJECT_ID', how='inner')
cat_19_mag3 = pd.merge(cat_18_mag3, cat3_err_21, on='OBJECT_ID', how='inner')
cat_20_mag3 = pd.merge(cat_19_mag3, cat3_err_22, on='OBJECT_ID', how='inner')
cat_21_mag3 = pd.merge(cat_20_mag3, cat3_err_23, on='OBJECT_ID', how='inner')
cat_22_mag3 = pd.merge(cat_21_mag3, cat3_err_24, on='OBJECT_ID', how='inner')

cat_1_mag4 = pd.merge(cat4_err_2, cat4_err_3, on='OBJECT_ID', how='inner')
cat_2_mag4 = pd.merge(cat_1_mag4, cat4_err_4, on='OBJECT_ID', how='inner')
cat_3_mag4 = pd.merge(cat_2_mag4, cat4_err_5, on='OBJECT_ID', how='inner')
cat_4_mag4 = pd.merge(cat_3_mag4, cat4_err_6, on='OBJECT_ID', how='inner')
cat_5_mag4 = pd.merge(cat_4_mag4, cat4_err_7, on='OBJECT_ID', how='inner')
cat_6_mag4 = pd.merge(cat_5_mag4, cat4_err_8, on='OBJECT_ID', how='inner')
cat_7_mag4 = pd.merge(cat_6_mag4, cat4_err_9, on='OBJECT_ID', how='inner')
cat_8_mag4 = pd.merge(cat_7_mag4, cat4_err_10, on='OBJECT_ID', how='inner')
cat_9_mag4 = pd.merge(cat_8_mag4, cat4_err_11, on='OBJECT_ID', how='inner')
cat_10_mag4 = pd.merge(cat_9_mag4, cat4_err_12, on='OBJECT_ID', how='inner')
cat_11_mag4 = pd.merge(cat_10_mag4, cat4_err_13, on='OBJECT_ID', how='inner')
cat_12_mag4 = pd.merge(cat_11_mag4, cat4_err_14, on='OBJECT_ID', how='inner')
cat_13_mag4 = pd.merge(cat_12_mag4, cat4_err_15, on='OBJECT_ID', how='inner')
cat_14_mag4 = pd.merge(cat_13_mag4, cat4_err_16, on='OBJECT_ID', how='inner')
cat_15_mag4 = pd.merge(cat_14_mag4, cat4_err_17, on='OBJECT_ID', how='inner')
cat_16_mag4 = pd.merge(cat_15_mag4, cat4_err_18, on='OBJECT_ID', how='inner')
cat_17_mag4 = pd.merge(cat_16_mag4, cat4_err_19, on='OBJECT_ID', how='inner')
cat_18_mag4 = pd.merge(cat_17_mag4, cat4_err_20, on='OBJECT_ID', how='inner')
cat_19_mag4 = pd.merge(cat_18_mag4, cat4_err_21, on='OBJECT_ID', how='inner')
cat_20_mag4 = pd.merge(cat_19_mag4, cat4_err_22, on='OBJECT_ID', how='inner')
cat_21_mag4 = pd.merge(cat_20_mag4, cat4_err_23, on='OBJECT_ID', how='inner')
cat_22_mag4 = pd.merge(cat_21_mag4, cat4_err_24, on='OBJECT_ID', how='inner')
# Out:
# <ipython-input-108-7638d1a782fa>:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'DATE-OBS_4_mag_0_x', '4_mag_err_0_x', 'DATE-OBS_2_mag_1_x', 'RA_x', 'DEC_x', '2_mag_err_1_x', '1_mag_err_0_x', '3_mag_err_0_x', 'DATE-OBS_1_mag_0_x', 'DATE-OBS_3_mag_0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   cat_3_mag1 = pd.merge(cat_2_mag1, cat1_err_5, on='OBJECT_ID', how='inner')
# <ipython-input-108-7638d1a782fa>:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'DATE-OBS_4_mag_0_x', '4_mag_err_0_x', 'DATE-OBS_2_mag_1_x', 'RA_x', 'DEC_x', '2_mag_err_1_x', '1_mag_err_0_x', '3_mag_err_0_x', 'DATE-OBS_1_mag_0_x', 'DATE-OBS_3_mag_0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   cat_5_mag1 = pd.merge(cat_4_mag1, cat1_err_7, on='OBJECT_ID', how='inner')
# ...

# %%
mag_1_alt = cat_22_mag1.sample(n=10)
mag_2_alt = cat_22_mag2.sample(n=10)
mag_3_alt = cat_22_mag3.sample(n=10)
mag_4_alt = cat_22_mag4.sample(n=10)

# %%
col1 = [f'mag1_{i}' for i in range(2, 25, 1)]

# %%
def grafico_est1(df):
  indice = ['Estrella 1','Estrella 2','Estrella 3','Estrella 4','Estrella 5','Estrella 6','Estrella 7','Estrella 8','Estrella 9','Estrella 10']
  col1 = [f'mag1_{i}' for i in range(2, 25, 1)]
  new_df = df.set_index(pd.Index(indice))
  estrellas = list()
  for i in indice:
    estrellas.append(new_df.loc[i, col1].tolist())
  return estrellas

def grafico_est2(df):
  indice = ['Estrella 1','Estrella 2','Estrella 3','Estrella 4','Estrella 5','Estrella 6','Estrella 7','Estrella 8','Estrella 9','Estrella 10']
  col1 = [f'mag2_{i}' for i in range(2, 25, 1)]
  new_df = df.set_index(pd.Index(indice))
  estrellas = list()
  for i in indice:
    estrellas.append(new_df.loc[i, col1].tolist())
  return estrellas

def grafico_est3(df):
  indice = ['Estrella 1','Estrella 2','Estrella 3','Estrella 4','Estrella 5','Estrella 6','Estrella 7','Estrella 8','Estrella 9','Estrella 10']
  col1 = [f'mag3_{i}' for i in range(2, 25, 1)]
  new_df = df.set_index(pd.Index(indice))
  estrellas = list()
  for i in indice:
    estrellas.append(new_df.loc[i, col1].tolist())
  return estrellas

def grafico_est4(df):
  indice = ['Estrella 1','Estrella 2','Estrella 3','Estrella 4','Estrella 5','Estrella 6','Estrella 7','Estrella 8','Estrella 9','Estrella 10']
  col1 = [f'mag4_{i}' for i in range(2, 25, 1)]
  new_df = df.set_index(pd.Index(indice))
  estrellas = list()
  for i in indice:
    estrellas.append(new_df.loc[i, col1].tolist())
  return estrellas

# %%
val_stars_1=grafico_est1(mag_1_alt)
val_stars_2=grafico_est2(mag_2_alt)
val_stars_3=grafico_est3(mag_3_alt)
val_stars_4=grafico_est4(mag_4_alt)
aperturas = range(2, 25, 1)

# %%
plt.figure(figsize=(8, 6))
plt.plot(aperturas,val_stars_1[0],label='Estrella 1')
plt.plot(aperturas,val_stars_1[1],label='Estrella 2')
plt.plot(aperturas,val_stars_1[2],label='Estrella 3')
plt.plot(aperturas,val_stars_1[3],label='Estrella 4')
plt.plot(aperturas,val_stars_1[4],label='Estrella 5')
plt.plot(aperturas,val_stars_1[5],label='Estrella 6')
plt.plot(aperturas,val_stars_1[6],label='Estrella 7')
plt.plot(aperturas,val_stars_1[7],label='Estrella 8')
plt.plot(aperturas,val_stars_1[8],label='Estrella 9')
plt.plot(aperturas,val_stars_1[9],label='Estrella 10')
#plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.plot(aperturas,val_stars_1[0],label='Estrella 1')
plt.plot(aperturas,val_stars_1[1],label='Estrella 2')
plt.plot(aperturas,val_stars_1[2],label='Estrella 3')
plt.plot(aperturas,val_stars_1[3],label='Estrella 4')
plt.plot(aperturas,val_stars_1[4],label='Estrella 5')
plt.plot(aperturas,val_stars_1[5],label='Estrella 6')
plt.plot(aperturas,val_stars_1[6],label='Estrella 7')
plt.plot(aperturas,val_stars_1[7],label='Estrella 8')
plt.plot(aperturas,val_stars_1[8],label='Estrella 9')
plt.plot(aperturas,val_stars_1[9],label='Estrella 10')
plt.title('[3.6] $\mu m$',fontsize=14)
plt.xlabel('Apertura',fontsize=12)
plt.ylabel('Magnitud',fontsize=12)
plt.xticks(aperturas)
plt.grid(True)
plt.legend(fontsize=7)

# %%
plt.figure(figsize=(15, 5))

plt.plot(aperturas,val_stars_2[0],label='Estrella 1')
plt.plot(aperturas,val_stars_2[1],label='Estrella 2')
plt.plot(aperturas,val_stars_2[2],label='Estrella 3')
plt.plot(aperturas,val_stars_2[3],label='Estrella 4')
plt.plot(aperturas,val_stars_2[4],label='Estrella 5')
plt.plot(aperturas,val_stars_2[5],label='Estrella 6')
plt.plot(aperturas,val_stars_2[6],label='Estrella 7')
plt.plot(aperturas,val_stars_2[7],label='Estrella 8')
plt.plot(aperturas,val_stars_2[8],label='Estrella 9')
plt.plot(aperturas,val_stars_2[9],label='Estrella 10')
plt.title('[4.5] $\mu m$',fontsize=14)
plt.xlabel('Apertura',fontsize=12)
plt.ylabel('Magnitud',fontsize=12)
plt.xticks(aperturas)
plt.grid(True)
plt.legend(fontsize=7)

# %%
plt.figure(figsize=(15, 5))

plt.plot(aperturas,val_stars_3[0],label='Estrella 1')
plt.plot(aperturas,val_stars_3[1],label='Estrella 2')
plt.plot(aperturas,val_stars_3[2],label='Estrella 3')
plt.plot(aperturas,val_stars_3[3],label='Estrella 4')
plt.plot(aperturas,val_stars_3[4],label='Estrella 5')
plt.plot(aperturas,val_stars_3[5],label='Estrella 6')
plt.plot(aperturas,val_stars_3[6],label='Estrella 7')
plt.plot(aperturas,val_stars_3[7],label='Estrella 8')
plt.plot(aperturas,val_stars_3[8],label='Estrella 9')
plt.plot(aperturas,val_stars_3[9],label='Estrella 10')
plt.title('[5.8] $\mu m$',fontsize=14)
plt.xlabel('Apertura',fontsize=12)
plt.ylabel('Magnitud',fontsize=12)
plt.xticks(aperturas)
plt.grid(True)
plt.legend(fontsize=7)

# %%
plt.figure(figsize=(15, 5))

plt.plot(aperturas,val_stars_4[0],label='Estrella 1')
plt.plot(aperturas,val_stars_4[1],label='Estrella 2')
plt.plot(aperturas,val_stars_4[2],label='Estrella 3')
plt.plot(aperturas,val_stars_4[3],label='Estrella 4')
plt.plot(aperturas,val_stars_4[4],label='Estrella 5')
plt.plot(aperturas,val_stars_4[5],label='Estrella 6')
plt.plot(aperturas,val_stars_4[6],label='Estrella 7')
plt.plot(aperturas,val_stars_4[7],label='Estrella 8')
plt.plot(aperturas,val_stars_4[8],label='Estrella 9')
plt.plot(aperturas,val_stars_4[9],label='Estrella 10')
plt.title('[8.0] $\mu m$',fontsize=14)
plt.xlabel('Apertura',fontsize=12)
plt.ylabel('Magnitud',fontsize=12)
plt.xticks(aperturas)
plt.grid(True)
plt.legend(fontsize=7,loc='upper right')

# %%
fig, axs = plt.subplots(4, 1, figsize=(10, 10))

# Graficar los datos en cada subgráfico
axs[0].plot(aperturas,val_stars_1[0],label='Estrella 1')
axs[0].plot(aperturas,val_stars_1[1],label='Estrella 2')
axs[0].plot(aperturas,val_stars_1[2],label='Estrella 3')
axs[0].plot(aperturas,val_stars_1[3],label='Estrella 4')
axs[0].plot(aperturas,val_stars_1[4],label='Estrella 5')
axs[0].plot(aperturas,val_stars_1[5],label='Estrella 6')
axs[0].plot(aperturas,val_stars_1[6],label='Estrella 7')
axs[0].plot(aperturas,val_stars_1[7],label='Estrella 8')
axs[0].plot(aperturas,val_stars_1[8],label='Estrella 9')
axs[0].plot(aperturas,val_stars_1[9],label='Estrella 10')
axs[0].set_title('Magnitud 1')
axs[0].set_xlabel('Apertura')
axs[0].set_ylabel('Magnitud')
axs[0].set_xticks(aperturas)
axs[0].grid(True)
axs[0].legend(fontsize=7)

axs[1].plot(aperturas,val_stars_2[0],label='Estrella 1')
axs[1].plot(aperturas,val_stars_2[1],label='Estrella 2')
axs[1].plot(aperturas,val_stars_2[2],label='Estrella 3')
axs[1].plot(aperturas,val_stars_2[3],label='Estrella 4')
axs[1].plot(aperturas,val_stars_2[4],label='Estrella 5')
axs[1].plot(aperturas,val_stars_2[5],label='Estrella 6')
axs[1].plot(aperturas,val_stars_2[6],label='Estrella 7')
axs[1].plot(aperturas,val_stars_2[7],label='Estrella 8')
axs[1].plot(aperturas,val_stars_2[8],label='Estrella 9')
axs[1].plot(aperturas,val_stars_2[9],label='Estrella 10')
axs[1].set_title('Magnitud 2')
axs[1].set_xlabel('Apertura')
axs[1].set_ylabel('Magnitud')
axs[1].grid(True)
axs[1].legend(fontsize=7)

axs[2].plot(aperturas,val_stars_3[0],label='Estrella 1')
axs[2].plot(aperturas,val_stars_3[1],label='Estrella 2')
axs[2].plot(aperturas,val_stars_3[2],label='Estrella 3')
axs[2].plot(aperturas,val_stars_3[3],label='Estrella 4')
axs[2].plot(aperturas,val_stars_3[4],label='Estrella 5')
axs[2].plot(aperturas,val_stars_3[5],label='Estrella 6')
axs[2].plot(aperturas,val_stars_3[6],label='Estrella 7')
axs[2].plot(aperturas,val_stars_3[7],label='Estrella 8')
axs[2].plot(aperturas,val_stars_3[8],label='Estrella 9')
axs[2].plot(aperturas,val_stars_3[9],label='Estrella 10')
axs[2].set_title('Magnitud 3')
axs[2].set_xlabel('Apertura')
axs[2].set_ylabel('Magnitud')
axs[2].grid(True)
axs[2].legend(fontsize=7)

axs[3].plot(aperturas,val_stars_4[0],label='Estrella 1')
axs[3].plot(aperturas,val_stars_4[1],label='Estrella 2')
axs[3].plot(aperturas,val_stars_4[2],label='Estrella 3')
axs[3].plot(aperturas,val_stars_4[3],label='Estrella 4')
axs[3].plot(aperturas,val_stars_4[4],label='Estrella 5')
axs[3].plot(aperturas,val_stars_4[5],label='Estrella 6')
axs[3].plot(aperturas,val_stars_4[6],label='Estrella 7')
axs[3].plot(aperturas,val_stars_4[7],label='Estrella 8')
axs[3].plot(aperturas,val_stars_4[8],label='Estrella 9')
axs[3].plot(aperturas,val_stars_4[9],label='Estrella 10')
axs[3].set_title('Magnitud 4')
axs[3].set_xlabel('Apertura')
axs[3].set_ylabel('Magnitud')
axs[3].grid(True)
axs[3].legend(fontsize=7)

# Puedes seguir este patrón para los otros dos subgráficos

plt.tight_layout()
plt.show()
